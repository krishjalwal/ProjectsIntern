# %% [markdown]
# <a href="https://colab.research.google.com/github/krishjalwal/ProjectsIntern/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
from pandas import DataFrame as df
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('cost_revenue_clean.csv')

# %%
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
x = df(data,columns=['production_budget_usd'])
y = df(data,columns=['worldwide_gross_usd'])

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y,alpha=0.3)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('WorldWide Gross $')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %% [markdown]
# Now For Linear Regression :
#
# ho(x) = Oo + O1x choose Oo and O1 as y = c + mx
# minimise : summation from i = 1 to n (yi - ho(xi))^2
#
# This is called **Residual Sum of Squares**

# %%
regression = LinearRegression()
regression.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# Slope Coefficient:

# %%
regression.coef_  #theta_1
# Out:
# array([[3.11150918]])

# %%
regression.intercept_  #theta_2
# Out:
# array([-7236192.72913958])

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y,alpha=0.3)
plt.plot(x,regression.predict(x),color='red',linewidth = 4)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('WorldWide Gross $')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %% [markdown]
# GoodNess of Fit : R^2
# Now Predict revenue for a film with a $50 million budget.
# theta1 and theta0 calculated above into the equation - theta0 + theta1x here x will be $50 million budget

# %% [markdown]
# real world data , how good our prediction

# %%
regression.score(x,y)
# Out:
# 0.5496485356985729
